# %% [markdown]
# ### Histograms
#
# Histograms are an excellent way to graph `continuous` variables because they show the distribution of values.
# Here's a histogram representing the distribution of `fat` percentages in food items.
# The `X-axis` represents the %fat, and the Y-axis shows the frequency of each bin.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample dataset: Percentages of fat in some food items
np.random.seed(0) # set seed for reproducibility
fat_percentage = np.random.normal(25, 5, 1000) # mean 25%, std 10%, 1000 samples

# Sample dataset: Body fat percentages for adolescent girls
fat_percentage2 =[
    26.76, 25.40, 25.98, 27.24, 26.87, 24.02, 25.95, 24.85, 24.90, 25.41, 25.14, 26.45, 25.76, 25.12, 25.44, 
    25.33, 26.49, 24.79, 25.31, 24.15, 22.45, 25.65, 25.86, 24.26, 27.27, 23.55, 25.05, 24.81, 26.53, 26.47, 
    25.15, 25.38, 24.11, 23.02, 24.65, 25.16, 26.23, 26.20, 24.61, 24.70, 23.95, 23.58, 23.29, 26.95, 24.49, 
    24.56, 23.75, 25.78, 23.39, 24.79, 24.10, 25.39, 24.49, 23.82, 24.97, 25.43, 25.07, 25.30, 24.37, 24.64, 
    24.33, 24.64, 24.19, 23.27, 25.18, 24.60, 23.37, 25.46, 24.09, 25.05, 25.73, 25.13, 26.14, 23.77, 25.40, 
    24.32, 24.13, 24.42, 24.69, 25.06, 23.83, 25.90, 25.47, 23.46, 26.49, 26.90, 26.18, 24.82, 23.93, 26.05, 
    24.60, 26.22
]

# Create histogram
plt.figure(figsize=(6, 4))
plt.hist(fat_percentage2, bins=15, color='skyblue', edgecolor='black')
plt.title('Histogram of % Fat in Food items')
plt.title('Histogram of % Fat for Adolescent girls')
plt.xlabel('% Fat')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Scatterplot
#
# When you have `two` continuous variables, you can graph them using a scatterplot.
# Scatterplots are great for displaying the `relationship` between two continuous variables.
# To plot a scatterplot of %Fat versus BMI, you'll need `two` arrays or lists: one for %Fat and another for BMI.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample dataset: random (%Fat vs BMI)
np.random.seed(0) # for reproducibility
percent_fat = np.random.normal(25, 1.5, 100) # mean 25%, std 1.5%, 100 samples
BMI = np.random.normal(20, 3, 100)

# Create scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(percent_fat, BMI, alpha=0.75, color='red', marker='o', edgecolor='black', s=50)

# Labels and title
plt.title('Scatter plot of % Fat vs BMI')
plt.xlabel('% Fat')
plt.ylabel('BMI')

# Show plot
plt.show()

# %% [markdown]
# ### Bar Charts
#
# Bar charts are a standard way to graph `discrete` variables.
# Each bar represents a distinct value, and the height represents its `proportion` in the entire sample.

# %%
import matplotlib.pyplot as plt

# Assume this is the result of a survey of 1000 households
# '0' for no car, '1' for one car, '2' for two cars, etc.
car_counts = [250, 400, 200, 100, 50]  # hypothetical distribution of car counts

# Corresponding number of cars in household
num_cars = ['0', '1', '2', '3', '4+']

# Creating the bar chart
plt.figure(figsize=(6, 4))
plt.bar(num_cars, car_counts, color='lightgreen', edgecolor='black')

# Adding title and labels
plt.title('Count of Cars in Households')
plt.xlabel('Number of Cars')
plt.ylabel('Number of Households')

# Show plot
plt.show()

# %% [markdown]
# ### Pie Charts
#
# Pie charts are great for highlighting the `proportions` that groups comprise of the whole.
# You can use them `with` categorical, binary, and ordinal data that define groups in your sample.

# %%
import matplotlib.pyplot as plt

# Sample data: New car colors in 2012
colors = ['Silver', 'Black', 'White', 'Red', 'Blue', 'Other']
percentages = [23, 19, 16, 14, 12, 16]

# Create the pie chart
plt.figure(figsize=(6, 6))
plt.pie(percentages, labels=colors, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)

# Add a title
plt.title('New Car Colors in 2022')

# Show the pie chart
plt.show()

# %% [markdown]
# ### Ordinal Variables / Histogram
#
# Ordinal data have at `least` three categories, and the categories have a natural order.
# Ordinal variables have a `combination` of qualitative and quantitative properties.
# On the one hand, hese variables have a `limited` number of discrete values like categorical variables.

# %%
import matplotlib.pyplot as plt

# Service rating categories
ratings = ['Very Poor', 'Poor', 'Average', 'Good', 'Very Good']

# Count or percentage of responses for each rating (example data)
responses = [5, 10, 50, 20, 15]

# Creating the bar chart
plt.figure(figsize=(6, 4))
plt.bar(ratings, responses, color='mediumpurple', edgecolor='black')

# Adding title and labels
plt.title('Rating of Service')
plt.xlabel('Rating')
plt.ylabel('Number of Responses')

# Show plot
plt.show()

# %% [markdown]
# ### Overlapping / Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating data for boys and girls with a slight difference in distribution
np.random.seed(0)
boys_percent_fat = np.random.normal(25, 1.5, 92)
girls_percent_fat = np.random.normal(24, 1.5, 92)

# Creating overlapping histograms
plt.figure(figsize=(6, 4))

plt.hist(boys_percent_fat, bins=15, alpha=0.5, label='Boys', color='blue')
plt.hist(girls_percent_fat, bins=15, alpha=0.5, label='Girls', color='red', edgecolor='white')

# Adding title and labels
plt.title('Overlapping Histogram of %Fat for Boys and Girls')
plt.xlabel('%Fat')
plt.ylabel('Frequency')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ### References
#
# https://www.amazon.com/Introduction-Statistics-Intuitive-Analyzing-Discoveries/dp/1735431109
